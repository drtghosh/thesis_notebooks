# %%
from create_data import DumbCirc as dc
from dklsuq import DeepKernelSUQ as dklu
import matplotlib
import matplotlib.pyplot as plt

# %%
data_instance = dc(0.5, 0.5, 0.25)
fc, pc, tc = data_instance.create_dataset(50, 2, [50], [0.2], True)

# %%
import torch
torch.manual_seed(22)
fc, pc, tc = torch.tensor(fc), torch.tensor(pc), torch.tensor(tc)

# %%
model_diag = dklu(point_cloud=fc, partial_cloud=pc, test_partial=tc)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model_diag.set_device(device)

# %%
model_diag.set_test_data(tc)

# %%
model_diag.train_diagonal()
# Out:
# Epoch:0, Loss: 0.6024996161460876
# Epoch:1, Loss: 0.7243459665775299
# Epoch:2, Loss: 0.747443166255951
# Epoch:3, Loss: 0.7428809457778931
# Epoch:4, Loss: 0.7417792450141907
# Epoch:5, Loss: 0.7368682219734192
# Epoch:6, Loss: 0.7383295991847991
# Epoch:7, Loss: 0.7311615665521239
# Epoch:8, Loss: 0.7377798859231872
# Epoch:9, Loss: 0.7349744559119781
# Epoch:10, Loss: 0.7280531072773664
# Epoch:11, Loss: 0.7313222138913101
# Epoch:12, Loss: 0.7346242576605404
# Epoch:13, Loss: 0.7291617137147253
# Epoch:14, Loss: 0.7225676485290778
# Epoch:15, Loss: 0.7226765574691822
# Epoch:16, Loss: 0.7193795705175028
# Epoch:17, Loss: 0.7206808321542665
# Epoch:18, Loss: 0.7173062978757844
# Epoch:19, Loss: 0.6987780296519086

# %%
model_diag.predict()

# %%
model_diag.set_test_data(pc[:2, :])

# %%
model_diag.predict()
