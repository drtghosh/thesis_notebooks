# %%
from create_data import DumbCirc as dc
from dklsuq import DeepKernelSUQ as dklu
import matplotlib
import matplotlib.pyplot as plt

# %%
data_instance = dc(0.5, 0.5, 0.25, 26)
fc, pc, tc = data_instance.create_dataset(50, 2, [100], [0.2], True)

# %%
import torch
torch.manual_seed(26)
fc, pc, tc = torch.tensor(fc), torch.tensor(pc), torch.tensor(tc)

# %%
model = dklu(point_cloud=fc, partial_cloud=pc, test_partial=tc)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model.set_device(device)

# %%
model.set_test_data(tc)

# %%
model.train_without_mapping(num_epochs=20, batch_size=20, learning_rate=0.1)
# Out:
# /servers/ash/hdd-home3/dghosh/Documents/Thesis/1notebooks/dklsuq.py:140: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1724788960438/work/aten/src/ATen/native/TensorShape.cpp:3697.)
#   + posterior_mean.T @ torch.linalg.inv(posterior_var) @ posterior_mean)
# Epoch:0, Loss: 6401.725
# Epoch:1, Loss: 7682.070000000019
# Epoch:2, Loss: 7938.1389999999665
# Epoch:3, Loss: 7989.352799999993
# Epoch:4, Loss: 7999.595559999999
# Epoch:5, Loss: 8001.644111999963
# Epoch:6, Loss: 8002.053822399956
# Epoch:7, Loss: 8002.13576448001
# Epoch:8, Loss: 8002.15215289602
# Epoch:9, Loss: 8002.155430579185
# Epoch:10, Loss: 8002.156086115819
# Epoch:11, Loss: 8002.156217223126
# Epoch:12, Loss: 8002.156243444607
# Epoch:13, Loss: 8002.156248688884
# Epoch:14, Loss: 8002.15624973774
# Epoch:15, Loss: 8002.156249947567
# Epoch:16, Loss: 8002.156249989476
# Epoch:17, Loss: 8002.156249997858
# Epoch:18, Loss: 8002.156249999534
# Epoch:19, Loss: 8002.156249999907

# %%
model.predict()

# %%
model.set_test_data(pc[:2, :])

# %%
model.predict()
