# %%
from create_data import DumbCirc as dc
from create_data_single import Dumb as db
from create_data_single import Circ as cc
from augsuqdkl import AugmentedSUQDKL as auq
import matplotlib
import matplotlib.pyplot as plt

# %%
data_instance = cc(0.4, 0.4, 0.2, 22)
fpc, fnc, pc, lp, tc, lt = data_instance.create_dataset(50, 1, [100], [0.2], True, 10)

# %%
import torch
torch.manual_seed(22)
fpc, fnc, pc, lp, tc, lt = torch.tensor(fpc), torch.tensor(fnc), torch.tensor(pc), torch.tensor(lp), torch.tensor(tc), torch.tensor(lt)

# %%
model_bin = auq(point_cloud=fpc, partial_cloud=pc, test_partial=tc, train_labels=lp,  mapping_dim=5, grid_size=125, negative_cloud=fnc)

# %%
use_cuda = torch.cuda.is_available()
#device = torch.device("cuda" if use_cuda else "cpu")
device = "cpu"
model_bin.set_device(device)

# %%
model_bin.train(num_epochs=20, batch_size=20, learning_rate=0.00001, kind='b')
# Out:
# /servers/ash/hdd-home3/dghosh/Documents/Thesis/1notebooks/augsuqdkl.py:231: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1724788960438/work/aten/src/ATen/native/TensorShape.cpp:3697.)
#   + posterior_mean_pos.T @ torch.linalg.inv(posterior_var_pos) @ posterior_mean_pos
# Epoch:0, Loss: 9.541392962137857
# Epoch:1, Loss: 11.148594114515516
# Epoch:2, Loss: 11.432033450515183
# Epoch:3, Loss: 14.16178763942954
# Epoch:4, Loss: 14.207028273201773
# Epoch:5, Loss: 14.195877036603553
# Epoch:6, Loss: 14.167113927057143
# Epoch:7, Loss: 14.02375210227263
# Epoch:8, Loss: 18.56907491187815
# Epoch:9, Loss: 16.734205021793855
# Epoch:10, Loss: 15.699255868572399
# Epoch:11, Loss: 14.86874355368429
# Epoch:12, Loss: 13.922150497610746
# Epoch:13, Loss: 13.398054084835906
# Epoch:14, Loss: 13.776654548664377
# Epoch:15, Loss: 14.422590357469018
# Epoch:16, Loss: 14.408481313919523
# Epoch:17, Loss: 13.98605210057083
# Epoch:18, Loss: 14.40637129701238
# Epoch:19, Loss: 12.75186083766176

# %%
model_bin.set_test_data(tc, lt)

# %%
model_bin.predict()
# Out:
# tensor([[1.0000e+00, 9.9793e-01, 9.9425e-01,  ..., 1.0133e-09, 2.0554e-09,
#          1.8085e-03],
#         [9.9793e-01, 1.0000e+00, 9.9859e-01,  ..., 1.4445e-09, 2.8875e-09,
#          1.9974e-03],
#         [9.9425e-01, 9.9859e-01, 1.0000e+00,  ..., 1.8185e-09, 3.5866e-09,
#          2.0667e-03],
#         ...,
#         [1.0133e-09, 1.4445e-09, 1.8185e-09,  ..., 1.0000e+00, 9.4120e-01,
#          1.1196e-04],
#         [2.0554e-09, 2.8876e-09, 3.5866e-09,  ..., 9.4120e-01, 1.0000e+00,
#          3.3512e-04],
#         [1.8085e-03, 1.9974e-03, 2.0667e-03,  ..., 1.1196e-04, 3.3512e-04,
#          1.0000e+00]], grad_fn=<AddBackward0>)
# tensor([-0.0078, -0.0096, -0.0102,  ..., -0.0334, -0.0327, -0.0320],
#        grad_fn=<MvBackward0>)

# %%
model_bin.set_test_data(pc[1:3, :], lp[1:3, :])

# %%
model_bin.predict()
# Out:
# tensor([[1.0000e+00, 9.9736e-01, 9.9002e-01,  ..., 9.6613e-02, 1.7413e-13,
#          4.2972e-01],
#         [9.9736e-01, 1.0000e+00, 9.9758e-01,  ..., 1.1215e-01, 2.9314e-13,
#          4.5675e-01],
#         [9.9002e-01, 9.9758e-01, 1.0000e+00,  ..., 1.2759e-01, 4.6183e-13,
#          4.7585e-01],
#         ...,
#         [9.6613e-02, 1.1215e-01, 1.2759e-01,  ..., 1.0000e+00, 2.4854e-07,
#          4.4131e-01],
#         [1.7413e-13, 2.9314e-13, 4.6183e-13,  ..., 2.4854e-07, 1.0000e+00,
#          5.0683e-10],
#         [4.2972e-01, 4.5675e-01, 4.7585e-01,  ..., 4.4131e-01, 5.0683e-10,
#          1.0000e+00]], grad_fn=<AddBackward0>)
# tensor([ 0.0001, -0.0011, -0.0024,  ...,  0.0022,  0.0022,  0.0022],
#        grad_fn=<MvBackward0>)
# tensor([[1.0000e+00, 9.9860e-01, 9.9428e-01,  ..., 4.9573e-06, 1.8282e-01,
#          2.4681e-07],
#         [9.9860e-01, 1.0000e+00, 9.9841e-01,  ..., 6.3659e-06, 1.7588e-01,
#          3.2525e-07],
#         [9.9428e-01, 9.9841e-01, 1.0000e+00,  ..., 8.2948e-06, 1.6799e-01,
#          4.3556e-07],
#         ...,
#         [4.9573e-06, 6.3659e-06, 8.2948e-06,  ..., 1.0000e+00, 6.3761e-08,
#          7.8348e-01],
#         [1.8282e-01, 1.7588e-01, 1.6799e-01,  ..., 6.3761e-08, 1.0000e+00,
#          4.9412e-09],
#         [2.4681e-07, 3.2525e-07, 4.3556e-07,  ..., 7.8348e-01, 4.9412e-09,
#          1.0000e+00]], grad_fn=<AddBackward0>)
# tensor([-0.0060, -0.0064, -0.0070,  ...,  0.0105,  0.0085,  0.0069],
#        grad_fn=<MvBackward0>)
