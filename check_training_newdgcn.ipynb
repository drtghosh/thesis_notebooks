# %%
from create_data_dgcn_cc import Circ as cc
from newdgcnsuq import DGCN as cn
import matplotlib
import matplotlib.pyplot as plt

# %%
data_instance = cc(0.4, 0.4, 0.2, 26)
fpc, fnc, pc, lp, tc, lt = data_instance.create_dataset(50, 2, [100], [0.2], 10)

# %%
pc.shape
# Out:
# (50, 56, 2)

# %%
import torch
torch.manual_seed(26)
fpc, fnc, pc, lp, tc, lt = torch.tensor(fpc), torch.tensor(fnc), torch.tensor(pc), torch.tensor(lp), torch.tensor(tc), torch.tensor(lt)

# %%
model = cn(pc, fpc, fnc, tc, lp, lt, False, 3)

# %%
model.train_kernel(num_epochs=50, learning_rate=0.0001, print_every=5)
# Out:
# C:\Users\Acer\Documents\All_of_RWTH\ThesisTarget\1MYWORK\thesis_notebooks\newdgcnsuq.py:12: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3679.)
#   dist_term = -0.5 * (label - mean).T @ torch.linalg.inv(variance) @ (label - mean)
# Epoch:0, Loss: -32.08557891845703
# Epoch:5, Loss: -31.992191314697266
# Epoch:10, Loss: -33.184871673583984
# Epoch:15, Loss: -33.76228713989258
# Epoch:20, Loss: -32.92538070678711
# Epoch:25, Loss: -33.63189697265625
# Epoch:30, Loss: -32.44304275512695
# Epoch:35, Loss: -34.22196578979492
# Epoch:40, Loss: -33.961673736572266
# Epoch:45, Loss: -34.53486251831055

# %%
model.predict()
# Out:
# tensor([[1.0000, 0.9997, 0.9994,  ..., 0.9768, 0.9769, 0.9771],
#         [0.9997, 1.0000, 0.9997,  ..., 0.9766, 0.9767, 0.9769],
#         [0.9994, 0.9997, 1.0000,  ..., 0.9764, 0.9765, 0.9766],
#         ...,
#         [0.9768, 0.9766, 0.9764,  ..., 1.0000, 0.9996, 0.9992],
#         [0.9769, 0.9767, 0.9765,  ..., 0.9996, 1.0000, 0.9996],
#         [0.9771, 0.9769, 0.9766,  ..., 0.9992, 0.9996, 1.0000]],
#        device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([[1.0000, 0.9842, 0.9972,  ..., 0.9895, 0.9941, 0.9984],
#         [0.9842, 1.0000, 0.9837,  ..., 0.9941, 0.9799, 0.9842],
#         [0.9972, 0.9837, 1.0000,  ..., 0.9886, 0.9933, 0.9988],
#         ...,
#         [0.9895, 0.9941, 0.9886,  ..., 1.0000, 0.9852, 0.9893],
#         [0.9941, 0.9799, 0.9933,  ..., 0.9852, 1.0000, 0.9935],
#         [0.9984, 0.9842, 0.9988,  ..., 0.9893, 0.9935, 1.0000]],
#        device='cuda:0', grad_fn=<MeanBackward1>)
