# %%
from create_data import DumbCirc as dc
from dklsuq import DeepKernelSUQ as dklu
import matplotlib
import matplotlib.pyplot as plt

# %%
data_instance = dc(0.5, 0.5, 0.25, 226)
fc, pc, tc = data_instance.create_dataset(100, 2, [100], [0.2], True)

# %%
import torch
fc, pc, tc = torch.tensor(fc), torch.tensor(pc), torch.tensor(tc)

# %%
model_diag = dklu(point_cloud=fc, partial_cloud=pc, test_partial=tc)

# %%
device = "cpu"

# %%
model_chol = dklu(point_cloud=fc, partial_cloud=pc, test_partial=tc)

# %%
model_chol.set_device(device)

# %%
model_chol.train_cholesky(num_epochs=20, learning_rate=0.0002)
# Out:
# /servers/ash/hdd-home3/dghosh/Documents/Thesis/1notebooks/dklsuq.py:199: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1724788960438/work/aten/src/ATen/native/TensorShape.cpp:3697.)
# Epoch:0, Loss: 15.000654954176683
# Epoch:1, Loss: 356.4300886865198
# Epoch:2, Loss: 1057.465720886418
# Epoch:3, Loss: 12882.801302964446
# Epoch:4, Loss: 5219.547771384698
# Epoch:5, Loss: -1043.7737764265
# Epoch:6, Loss: -569.1008009830031
# Epoch:7, Loss: 212.5984457829143
# Epoch:8, Loss: 530.9511231558334
# Epoch:9, Loss: 482.2310409482994
# Epoch:10, Loss: 374.58481839938565
# Epoch:11, Loss: 1075.8301480027678
# Epoch:12, Loss: 341.74670214081914
# Epoch:13, Loss: -988.6346500144363
# Epoch:14, Loss: 373.547304096696
# Epoch:15, Loss: 353.7057297002717
# Epoch:16, Loss: 66.47710501056027
# Epoch:17, Loss: -486.4833660959425
# Epoch:18, Loss: 1129.2132299799246
# Epoch:19, Loss: 755.9046275681297

# %%
model_chol.set_test_data(tc)

# %%
model_chol.predict()

# %%
model_chol.set_test_data(pc[:2, :])

# %%
model_chol.predict()
