# %%
import torch

# %%
x = torch.randn(20, 2, 3)
y = torch.randn(20, 2)

# %%
z = x * y [..., None]

# %%
z = torch.permute(z, (2, 0, 1))

# %%
torch.exp(-0.5*torch.cdist(z, z)).mean(dim=0)
# Out:
# tensor([[1.0000, 0.7330, 0.7301, 0.5627, 0.5227, 0.7554, 0.7758, 0.5971, 0.6453,
#          0.8851, 0.8827, 0.5812, 0.6824, 0.6405, 0.6914, 0.7413, 0.6104, 0.4212,
#          0.9032, 0.8981],
#         [0.7330, 1.0000, 0.6280, 0.6124, 0.5738, 0.6218, 0.6648, 0.5298, 0.5260,
#          0.6671, 0.6800, 0.5479, 0.5560, 0.5216, 0.5466, 0.6157, 0.4550, 0.3844,
#          0.7655, 0.6714],
#         [0.7301, 0.6280, 1.0000, 0.4663, 0.4275, 0.8350, 0.6944, 0.5392, 0.6198,
#          0.7644, 0.6598, 0.6517, 0.6917, 0.6852, 0.7512, 0.7634, 0.6309, 0.3982,
#          0.6596, 0.7660],
#         [0.5627, 0.6124, 0.4663, 1.0000, 0.3940, 0.4812, 0.4745, 0.4908, 0.5008,
#          0.5447, 0.5563, 0.5664, 0.4835, 0.4861, 0.4471, 0.5093, 0.4062, 0.2887,
#          0.5814, 0.5362],
#         [0.5227, 0.5738, 0.4275, 0.3940, 1.0000, 0.4599, 0.4954, 0.3882, 0.3874,
#          0.4769, 0.5238, 0.4283, 0.3947, 0.3317, 0.3479, 0.4459, 0.3844, 0.3848,
#          0.5242, 0.4842],
# ...
