# %%
from create_data import DumbCirc as dc
import matplotlib
import matplotlib.pyplot as plt

# %%
data_instance = dc(2.0, 2.0, 1.0)

# %%
fc, pc, tc = data_instance.create_dataset(10, 2, [100], [0.1], True)

# %%
# example
fig = plt.figure(figsize=(11, 4))
ax = fig.add_subplot(111)
plot = ax.scatter(pc[0][:, 0], pc[0][:, 1], s = 0.1)
ax.axis('equal')
ax.set_title(f'Subsamples on the Surface')
# Out:
# Text(0.5, 1.0, 'Subsamples on the Surface')

# %%
import torch
pc = torch.Tensor(pc)
pc.size()[:-1]
# Out:
# /tmp/ipykernel_188511/185225889.py:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403246168/work/torch/csrc/utils/tensor_new.cpp:275.)
#   pc = torch.Tensor(pc)
# torch.Size([20, 140])

# %%
pc.size()

# %%
import numpy as np
np.max(np.max(fc, 1), 0)

# %%
# example
fig = plt.figure(figsize=(11, 4))
ax = fig.add_subplot(111)
plot = ax.scatter(tc[:, 0], tc[:, 1], s = 0.1)
ax.axis('equal')
ax.set_title(f'Test Sample')

# %%
fc = torch.Tensor(fc)
torch.amin(fc, dim=(1,0))
