# %%
from create_data import DumbCirc as dc
import matplotlib
import matplotlib.pyplot as plt

# %%
data_instance = dc(2.0, 2.0, 1.0)

# %%
fc, pc = data_instance.create_dataset(10, [100], [0.1], True)

# %%
# example
fig = plt.figure(figsize=(11, 4))
ax = fig.add_subplot(111)
plot = ax.scatter(fc[0][:, 0], fc[0][:, 1], s = 0.1)
ax.axis('equal')
ax.set_title(f'Subsamples on the Surface')
# Out:
# Text(0.5, 1.0, 'Subsamples on the Surface')

# %%
import torch
pc = torch.Tensor(pc)
pc.size()[:-1]
# Out:
# torch.Size([20, 140])
